# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter 
from num2words import num2words 
import nltk
import os 
import string 
import numpy as np 
import copy 
import pandas as pd 
import pickle 
import re 
import math

# %%
title = "comp.graphics"

os.chdir("C:/Users/abodm/20_newsgroups")

paths = []

for (dirpath, dirname, filenames) in os.walk(str(os.getcwd())+"/"+title+""):
    for i in filenames:
        paths.append(str(dirpath)+str("\\")+i)

print('Real Path: '+dirpath)
print('My first file: '+paths[0])
# Out:
# Real Path: C:\Users\abodm\20_newsgroups/comp.graphics
# My first file: C:\Users\abodm\20_newsgroups/comp.graphics\39036

# %%
for i in range(len(filenames)):
    print(dirpath + "/" +filenames[i])
# Out:
# C:\Users\abodm\20_newsgroups/comp.graphics/39036
# C:\Users\abodm\20_newsgroups/comp.graphics/39037
# C:\Users\abodm\20_newsgroups/comp.graphics/39038
# C:\Users\abodm\20_newsgroups/comp.graphics/39039
# C:\Users\abodm\20_newsgroups/comp.graphics/39040
# C:\Users\abodm\20_newsgroups/comp.graphics/39051
# C:\Users\abodm\20_newsgroups/comp.graphics/39053
# C:\Users\abodm\20_newsgroups/comp.graphics/39059
# C:\Users\abodm\20_newsgroups/comp.graphics/39060
# C:\Users\abodm\20_newsgroups/comp.graphics/39063
# C:\Users\abodm\20_newsgroups/comp.graphics/39064
# C:\Users\abodm\20_newsgroups/comp.graphics/39066
# C:\Users\abodm\20_newsgroups/comp.graphics/39068
# C:\Users\abodm\20_newsgroups/comp.graphics/39070
# C:\Users\abodm\20_newsgroups/comp.graphics/39071
# C:\Users\abodm\20_newsgroups/comp.graphics/39072
# C:\Users\abodm\20_newsgroups/comp.graphics/39073
# C:\Users\abodm\20_newsgroups/comp.graphics/39074
# C:\Users\abodm\20_newsgroups/comp.graphics/39075
# C:\Users\abodm\20_newsgroups/comp.graphics/39076
# C:\Users\abodm\20_newsgroups/comp.graphics/39077
# C:\Users\abodm\20_newsgroups/comp.graphics/39078
# C:\Users\abodm\20_newsgroups/comp.graphics/39487
# C:\Users\abodm\20_newsgroups/comp.graphics/39488
# C:\Users\abodm\20_newsgroups/comp.graphics/39489
# C:\Users\abodm\20_newsgroups/comp.graphics/39490
# C:\Users\abodm\20_newsgroups/comp.graphics/39495
# C:\Users\abodm\20_newsgroups/comp.graphics/39496
# C:\Users\abodm\20_newsgroups/comp.graphics/39497
# C:\Users\abodm\20_newsgroups/comp.graphics/39498
# C:\Users\abodm\20_newsgroups/comp.graphics/39499
# C:\Users\abodm\20_newsgroups/comp.graphics/39500
# C:\Users\abodm\20_newsgroups/comp.graphics/39615
# C:\Users\abodm\20_newsgroups/comp.graphics/39617
# C:\Users\abodm\20_newsgroups/comp.graphics/39618
# C:\Users\abodm\20_newsgroups/comp.graphics/39619
# C:\Users\abodm\20_newsgroups/comp.graphics/39620
# C:\Users\abodm\20_newsgroups/comp.graphics/39621
# C:\Users\abodm\20_newsgroups/comp.graphics/39622
# C:\Users\abodm\20_newsgroups/comp.graphics/39623
# C:\Users\abodm\20_newsgroups/comp.graphics/39624
# C:\Users\abodm\20_newsgroups/comp.graphics/39736
# C:\Users\abodm\20_newsgroups/comp.graphics/39737
# C:\Users\abodm\20_newsgroups/comp.graphics/39738
# C:\Users\abodm\20_newsgroups/comp.graphics/40008
# C:\Users\abodm\20_newsgroups/comp.graphics/40027
# C:\Users\abodm\20_newsgroups/comp.graphics/40062

# %%
def remove_stop_words(data): 
 stop_words = stopwords.words('english') 
 words = word_tokenize(str(data)) 
 new_text = "" 
 for w in words: 
    if w not in stop_words: 
        new_text = new_text + " " + w 
 return np.char.strip(new_text) 
def remove_punctuation(data): 
 symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n" 
 for i in range(len(symbols)): 
    data = np.char.replace(data, symbols[i], ' ') 
    data = np.char.replace(data, " ", " ") 
 data = np.char.replace(data, ',', '') 
 return data 
def convert_lower_case(data): 
 return np.char.lower(data) 
def stemming(data): 
 stemmer= PorterStemmer() 
 tokens = word_tokenize(str(data)) 
 new_text = "" 
 for w in tokens: 
   new_text = new_text + " " + stemmer.stem(w) 
 return np.char.strip(new_text)
def convert_numbers(data): 
 data = np.char.replace(data, "0", " zero ") 
 data = np.char.replace(data, "1", " one ") 
 data = np.char.replace(data, "2", " two ") 
 data = np.char.replace(data, "3", " three ") 
 data = np.char.replace(data, "4", " four ") 
 data = np.char.replace(data, "5", " five ") 
 data = np.char.replace(data, "6", " six ") 
 data = np.char.replace(data, "7", " seven ") 
 data = np.char.replace(data, "8", " eight ") 
 data = np.char.replace(data, "9", " nine ") 
 return data 
def remove_header(data): 
 try: 
   ind = data.index('\n\n') 
   data = data[ind:] 
 except: 
   print("No Header") 
 return data 
def remove_apostrophe(data): 
 return np.char.replace(data, "'", "")
def remove_single_characters(data): 
 words = word_tokenize(str(data)) 
 new_text = "" 
 for w in words: 
   if len(w) > 1: 
      new_text = new_text + " " + w 
 return np.char.strip(new_text) 
 
def preprocess(data, query):
    if not query:
        data = remove_header(data)
    data = convert_lower_case(data)
    data = convert_numbers(data)
    data = remove_punctuation(data)
    data = remove_stop_words(data)
    data = remove_apostrophe(data)
    data = stemming(data)
    return data

# %%
processed_text = [] 
for i in range(len(filenames)): 
    file = open(dirpath+'/'+ filenames[i], 'r', encoding='cp1250', errors='ignore') 
    text = file.read().strip() 
    file.close() 


    processed_text.append(word_tokenize(str(preprocess(text,False)))) 
    print(processed_text)
# Out:
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'gen
 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c']]
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one
'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 
', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one
'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 
', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# ...
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', '
ger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# [['articl', 'one', 'nine', 'nine', 'three', 'may', 'one', 'zero', 'nine', 'two', 'zero', 'five', 'eight', 'one', 'aurora', 'alaska', 'edu', 'pstlb', 'aurora', 'alaska', 'edu', 'write', 'put', 'thu', 'hacker', 'ethic', 'gone', 'still', 'exist', 'exist', 'call', 'hacker', 'allow', 'perpetu', 'creat', 'new', 'innov', 'interest', 'idea', 'stop', 'so', 'maintain', 'choke', 'hold', 'comput', 'industri', 'gnu', 'peopl', 'hand', 'good', 'free', 'softwar', 've', 'also', 'distribut', 'two', 'decent', 'size', 'program', 'go', 'player', 'fumiko', 'ftp', 'u', 'washington', 'edu', 'genet', 'neural', 'network', 'programm', 'cerebrum', 'somewher', 've', 'time', 'write', 'program', 'scholarship', 'grant', 'intend', 'benefit', 'societi', 'loophol', 'system', 'peter', 'dudey', 'one', 'one', 'kyu', 'lisp', 'subguru', 'order', 'golden', 'parenthes', 'finger', 'reform', 'church', 'jame', 'eric', 'half', 'bee', 'dip', 'curri', 'shadowi', 'flight', 'danger', 'world', 'man', 'exist', 'pleas', 'mail', 'plastic', 'spaceship', 'nine', 'zero', 'zero', 'state', 'st', 'c', 'two', 'one', 'zero', 'salem', 'nine', 'seven', 'three', 'zero', 'one'], ['hacker', 'ethic', 'go', 'hacker', 'seven', 'zero', 's', 'eight', 'zero', 'comfort', 'employ', 'support', 'famili', 'next', 'gener', 'take', 'radic', 'lead', 'nt', 'look', 'radic', 'among', 'us', 'old', 'one', 're', 'gone', 'gradi', 'netcom', 'com', 'two', 'ef', 'two', 'two', 'one', 'one', 'five', 'e', 'two', 'ad', 'three', 'one', 'c', 'six', 'f', 'three', 'fc', 'five', 'eight', 'ac', 'f', 'seven', 'three', 'four', 'f', 'zero', 'one', 'one', 'e', 'two', 'f'], ['univers', 'toronto', 'instruct', 'research', 'comput', 'sponsor', 'technic', 'present', 'visual', 'softwar', '\x08a', '\x08d', '\x08v', '\x08a', '\x08n', '\x08c', '\x08e', '\x08d', '\x08v', '\x08i', '\x08s', '\x08u', '\x08a', '\x08l', '\x08s', '\x08y', '\x08s', '\x08t', '\x08e', '\x08m', '\x08s', '\x08a', '\x08v', '\x08s', '\x08s', '\x08o', '\x08f', '\x08t', '\x08w', '\x08a', '\x08r', '\x08e', 'two', 'one', 'zero', 'pm', 'four', 'zero', 'zero', 'pm', 'thursday', 'may', 'six', 'one', 'nine', 'nine', 'three', 'sandford', 'fleme', 'build', 'room', 'one', 'one', 'zero', 'five', 'advanc', 'visual', 'system', 'present', 'technic', 'seminar', 'av', 'world', 's', 'lead', 'visual', 'softwar', 'packag', 'av', 'point', 'click', 'modul', 'driven', 'easi', 'use', 'product', 'produc', 'full', 'color', 'two', 'three', 'dimension', 'render', 'scene', 'interact', 'observ', 'support', 'current', 'unix', 'risc', 'platform', 'sun', 'sgi', 'ibm', 'h', 'p', 'dg', 'dec', 'also', 'run', 'dec', 'vm', 'av', 'fourth', 'year', 'street', 'matur', 'field', 'scienc', 'engin', 'medicin', 'even', 'busi', 'applic', 'use', 'av', 'seminar', 'focu', 'mani', 'featur', 'technic', 'detail', 'half', 'hour', 'slide', 'present', 'follow', 'question', 'period', 'live', 'demonstr', 'use', 'sun', 'sparcstat', 'addit', 'new', 'av', 'program', 'call', 'campu', 'introduc', 'meet', 'also', 'discuss', 'intern', 'av', 'center', 'provid', 'line', 'repositori', 'one', 'zero', 'zero', 'zero', 'graphic', 'modul', 'north', 'carolina', 'supercomput', 'center', 'raliegh', 'nc', 'av', 'imbed', 'tool', 'write', 'one', 's', 'custom', 'modul', 'avail', 'av', 'av', 'intern', '\x08s', '\x08p', '\x08e', '\x08a', '\x08k', '\x08e', '\x08r', '\x08s', 'schedul', 'speaker', 'present', 'mr', 'paul', 'ecklund', 'ecklund', 'associ', 'distributor', 'av', 'canada', '\x08t', '\x08h', '\x08i', '\x08s', '\x08p', '\x08r', '\x08e', '\x08s', '\x08e', '\x08n', '\x08t', '\x08a', '\x08t', '\x08i', '\x08o', '\x08n', '\x08i', '\x08s', '\x08o', '\x08p', '\x08e', '\x08n', '\x08t', '\x08o', '\x08t', '\x08h', '\x08e', '\x08p', '\x08u', '\x08b', '\x08l', '\x08i', '\x08c'], ['articl', 'c', 'five', 'w', 'eight', 'xb', 'iv', 'six', 'world', 'std', 'com', 'sci', 'imag', 'processingcomp', 'graphic', 'wdm', 'world', 'std', 'com', 'wayn', 'michael', 'write', 'search', 'qualiti', 'imag', 'enhanc', 'manipul', 'packag', 'unix', 'x', 'motif', 'platform', 'comp ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
DF = {}

N = len(processed_text)

for i in range(N):
    tokens = processed_text[i]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}

for i in DF:
    DF[i]= len(DF[i])

# %%
DF
# Out:
# {'articl': 27,
#  'one': 67,
#  'nine': 41,
#  'three': 60,
#  'may': 23,
#  'zero': 56,
#  'two': 58,
#  'five': 48,
#  'eight': 37,
#  'aurora': 2,
#  'alaska': 2,
#  'edu': 38,
#  'pstlb': 2,
#  'write': 38,
#  'put': 7,
#  'thu': 6,
#  'hacker': 7,
#  'ethic': 6,
#  'gone': 6,
#  'still': 9,
#  'exist': 8,
#  'call': 13,
#  'allow': 12,
#  'perpetu': 2,
#  'creat': 16,
#  'new': 24,
#  'innov': 2,
#  'interest': 16,
#  'idea': 6,
#  'stop': 4,
#  'so': 2,
#  'maintain': 6,
#  'choke': 2,
#  'hold': 4,
#  'comput': 24,
#  'industri': 5,
#  'gnu': 4,
#  'peopl': 13,
#  'hand': 6,
#  'good': 11,
#  'free': 10,
#  'softwar': 21,
#  've': 17,
#  'also': 25,
#  'distribut': 8,
#  'decent': 1,
#  'size': 6,
#  'program': 26,
#  'go': 17,
#  'player': 2,
#  'fumiko': 1,
#  'ftp': 18,
#  'u': 4,
#  'washington': 1,
#  'genet': 2,
#  'neural': 3,
#  'network': 7,
#  'programm': 4,
#  'cerebrum': 1,
#  'somewher': 4,
#  'time': 16,
#  'scholarship': 1,
#  'grant': 2,
#  'intend': 4,
#  'benefit': 2,
#  'societi': 4,
#  'loophol': 1,
#  'system': 25,
#  'peter': 3,
#  'dudey': 1,
#  'kyu': 1,
#  'lisp': 2,
#  'subguru': 1,
#  'order': 9,
#  'golden': 1,
#  'parenthes': 1,
#  'finger': 5,
#  'reform': 1,
#  'church': 1,
#  'jame': 2,
#  'eric': 4,
#  'half': 5,
#  'bee': 1,
#  'dip': 1,
#  'curri': 1,
#  'shadowi': 1,
#  'flight': 1,
#  'danger': 1,
#  'world': 10,
#  'man': 2,
#  'pleas': 36,
#  'mail': 22,
#  'plastic': 1,
#  'spaceship': 1,
#  'state': 7,
#  'st': 5,
#  'c': 20,
#  'salem': 1,
#  'seven': 38,
#  's': 34,
#  'comfort': 2,
#  'employ': 3,
#  'support': 19,
#  'famili': 4,
#  'next': 6,
#  'gener': 15,
#  'take': 17,
#  'radic': 2,
#  'lead': 7,
#  'nt': 29,
#  'look': 27,
#  'among': 7,
#  'us': 11,
#  'old': 5,
#  're': 8,
#  'gradi': 1,
#  'netcom': 2,
#  'com': 25,
#  'ef': 1,
#  'e': 23,
#  'ad': 5,
#  'six': 47,
#  'f': 3,
#  'fc': 1,
#  'ac': 11,
#  'four': 48,
#  'univers': 12,
#  'toronto': 1,
#  'instruct': 4,
#  'research': 10,
#  'sponsor': 1,
#  'technic': 7,
#  'present': 3,
#  'visual': 4,
#  '\x08a': 1,
#  '\x08d': 1,
#  '\x08v': 1,
#  '\x08n': 1,
#  '\x08c': 1,
#  '\x08e': 1,
#  '\x08i': 1,
#  '\x08s': 1,
#  '\x08u': 1,
#  '\x08l': 1,
#  '\x08y': 1,
#  '\x08t': 1,
#  '\x08m': 1,
#  '\x08o': 1,
#  '\x08f': 1,
#  '\x08w': 1,
#  '\x08r': 1,
#  'pm': 4,
#  'thursday': 1,
#  'sandford': 1,
#  'fleme': 1,
#  'build': 2,
#  'room': 4,
#  'advanc': 17,
#  'seminar': 1,
#  'av': 2,
#  'packag': 13,
#  'point': 17,
#  'click': 3,
#  'modul': 3,
#  'driven': 1,
#  'easi': 6,
#  'use': 34,
#  'product': 6,
#  'produc': 7,
#  'full': 8,
#  'color': 14,
#  'dimension': 1,
#  'render': 7,
#  'scene': 6,
#  'interact': 2,
#  'observ': 3,
#  'current': 12,
#  'unix': 14,
#  'risc': 3,
#  'platform': 6,
#  'sun': 4,
#  'sgi': 5,
#  'ibm': 6,
#  'h': 8,
#  'p': 8,
#  'dg': 1,
#  'dec': 3,
#  'run': 16,
#  'vm': 4,
#  'fourth': 1,
#  'year': 6,
#  'street': 1,
#  'matur': 1,
#  'field': 4,
#  'scienc': 6,
#  'engin': 5,
#  'medicin': 1,
#  'even': 12,
#  'busi': 1,
#  'applic': 9,
#  'focu': 2,
#  'mani': 16,
#  'featur': 9,
#  'detail': 6,
#  'hour': 1,
#  'slide': 3,
#  'follow': 15,
#  'question': 10,
#  'period': 2,
#  'live': 6,
#  'demonstr': 2,
#  'sparcstat': 1,
#  'addit': 5,
#  'campu': 2,
#  'introduc': 5,
#  'meet': 3,
#  'discuss': 5,
#  'intern': 8,
#  'center': 5,
#  'provid': 7,
#  'line': 17,
#  'repositori': 1,
#  'graphic': 34,
#  'north': 4,
#  'carolina': 2,
#  'supercomput': 2,
#  'raliegh': 1,
#  'nc': 3,
#  'imbed': 1,
#  'tool': 7,
#  'custom': 3,
#  'avail': 15,
#  '\x08p': 1,
#  '\x08k': 1,
#  'schedul': 1,
#  'speaker': 1,
#  'mr': 3,
#  'paul': 3,
#  'ecklund': 1,
#  'associ': 4,
#  'distributor': 1,
#  'canada': 3,
#  '\x08h': 1,
#  '\x08b': 1,
#  'w': 8,
#  'xb': 1,
#  'iv': 1,
#  'std': 1,
#  'sci': 1,
#  'imag': 23,
#  'processingcomp': 1,
#  'wdm': 1,
#  'wayn': 1,
#  'michael': 2,
#  'search': 3,
#  'qualiti': 6,
#  'enhanc': 2,
#  'manipul': 4,
#  'x': 19,
#  'motif': 2,
#  'compar': 3,
#  'adob': 5,
#  'photo': 1,
#  'shop': 2,
#  'mac': 6,
#  'stuff': 10,
#  'delet': 5,
#  'understand': 7,
#  'work': 19,
#  'make': 22,
#  'photoshop': 3,
#  'indigo': 1,
#  'rumor': 1,
#  'would': 34,
#  'bet': 3,
#  'see': 9,
#  'releas': 4,
#  'illustr': 1,
#  'real': 5,
#  'soon': 1,
#  'charl': 3,
#  'boesel': 1,
#  'diablo': 1,
#  'creativ': 3,
#  'pro': 1,
#  'con': 1,
#  'cboesel': 1,
#  'uu': 3,
#  'holonet': 1,
#  'net': 8,
#  'opposit': 3,
#  'progress': 3,
#  'els': 5,
#  'congress': 1,
#  'apr': 3,
#  'nessi': 1,
#  'mcc': 1,
#  'uk': 6,
#  'lilley': 1,
#  'xv': 6,
#  'recommend': 5,
#  'mention': 6,
#  'type': 9,
#  'ah': 1,
#  'thew': 1,
#  'problem': 19,
#  'first': 13,
#  'want': 21,
#  'extend': 7,
#  'edit': 5,
#  'bit': 14,
#  'preview': 3,
#  'say': 17,
#  'person': 11,
#  'happen': 4,
#  'part': 5,
#  'caus': 6,
#  'previou': 4,
#  'debat': 1,
#  'rest': 5,
#  'agre': 6,
#  'view': 11,
#  'case': 6,
#  'opinion': 9,
#  'mean': 11,
#  'obviou': 1,
#  'thing': 12,
#  'contradict': 1,
#  'argument': 4,
#  'read': 11,
#  'saw': 4,
#  'refer': 6,
#  'text': 6,
#  'wrote': 5,
#  'someth': 11,
#  'hard': 6,
#  'decis': 3,
#  'without': 9,
#  'exactli': 5,
#  'written': 6,
#  'realli': 9,
#  'repli': 10,
#  'method': 6,
#  'includ': 10,
#  'previous': 3,
#  'materi': 5,
#  'sentenc': 1,
#  'give': 14,
#  'seem': 6,
#  'start': 5,
#  'ask': 12,
#  'repeatedli': 3,
#  'decsrib': 1,
#  'wrong': 2,
#  'post': 12,
#  'within': 5,
#  'believ': 6,
#  'nice': 7,
#  'get': 22,
#  'flame': 4,
#  'special': 4,
#  'know': 44,
#  'care': 4,
#  'place': 8,
#  'jpeg': 5,
#  'faq': 10,
#  'user': 12,
#  'm': 27,
#  'sure': 12,
#  'undertand': 1,
#  'blame': 1,
#  'skill': 2,
#  'english': 6,
#  'better': 10,
#  'check': 7,
#  'allreadi': 1,
#  'bradley': 2,
#  'juhana': 1,
#  'kouhia': 1,
#  'spec': 6,
#  'mpg': 2,
#  'file': 25,
#  'float': 4,
#  'around': 15,
#  'alt': 6,
#  'binari': 6,
#  'pictur': 14,
#  'group': 18,
#  'lem': 1,
#  'obtain': 4,
#  'email': 16,
#  'thank': 42,
#  'much': 18,
#  'murray': 2,
#  'add': 9,
#  'sdsu': 1,
#  'million': 3,
#  'site': 14,
#  'carri': 4,
#  'zip': 5,
#  'pov': 6,
#  'sourc': 13,
#  'jack': 6,
#  'kettl': 1,
#  'unfortun': 4,
#  'lost': 4,
#  'address': 15,
#  'littl': 6,
#  'hurri': 1,
#  'jtheinon': 1,
#  'kruuna': 1,
#  'helsinki': 1,
#  'fi': 1,
#  'jarkko': 1,
#  'dj': 2,
#  'wl': 1,
#  'cs': 7,
#  'columbia': 1,
#  'olasov': 1,
#  'benjamin': 1,
#  'welchgat': 1,
#  'welch': 1,
#  'jhu': 1,
#  'danj': 1,
#  'dan': 2,
#  'jacobson': 1,
#  'lot': 10,
#  'gopher': 4,
#  'never': 4,
#  'heard': 5,
#  'worri': 3,
#  'note': 8,
#  'd': 13,
#  'like': 30,
#  'inform': 17,
#  'best': 8,
#  'luck': 4,
#  'intro': 2,
#  'came': 2,
#  'back': 5,
#  'could': 18,
#  'think': 15,
#  'ben': 1,
#  'heavili': 4,
#  'modifi': 7,
#  'version': 10,
#  'enough': 9,
#  'client': 2,
#  'jump': 1,
#  'space': 7,
#  'complet': 13,
#  'describ': 5,
#  'merlot': 1,
#  'welcom': 6,
#  'common': 5,
#  'answer': 7,
#  'internet': 8,
#  'server': 6,
#  'protocol': 2,
#  'wide': 6,
#  'servic': 8,
#  'implement': 7,
#  'comp': 10,
#  'infosystem': 1,
#  'news': 5,
#  'everi': 6,
#  'week': 4,
#  'recent': 5,
#  'gotten': 3,
#  'via': 6,
#  'anonym': 8,
#  'rtfm': 3,
#  'mit': 4,
#  'pub': 4,
#  'usenet': 6,
#  'access': 11,
#  'send': 11,
#  'find': 19,
#  'bodi': 3,
#  'list': 10,
#  'q': 4,
#  'need': 20,
#  'publicli': 1,
#  'login': 3,
#  'develop': 8,
#  'relationship': 1,
#  'wai': 2,
#  'www': 1,
#  'paper': 3,
#  'veronica': 1,
#  'biolog': 2,
#  'deliveri': 1,
#  'cwi': 1,
#  'readili': 1,
#  'construct': 1,
#  'vehicl': 1,
#  'local': 3,
#  'facilit': 2,
#  'throughout': 1,
#  'boombox': 1,
#  'micro': 1,
#  'umn': 1,
#  'directori': 6,
#  'pc': 19,
#  'workstat': 4,
#  'name': 14,
#  'locat': 4,
#  'curs': 1,
#  'emac': 2,
#  'tar': 5,
#  'z': 9,
#  'xwindow': 1,
#  'athena': 2,
#  'xgopher': 1,
#  'moog': 1,
#  'xview': 2,
#  'xvgopher': 1,
#  'macintosh': 5,
#  'hypercard': 1,
#  'turbogoph': 1,
#  'do': 10,
#  'clarkson': 2,
#  'driver': 8,
#  'nextstep': 1,
#  'cm': 1,
#  'rice': 1,
#  'viegoph': 1,
#  'os': 4,
#  'mv': 1,
#  'xa': 1,
#  'other': 7,
#  'attempt': 5,
#  'comprehens': 1,
#  'microsoft': 4,
#  'window': 10,
#  'winsock': 1,
#  'book': 8,
#  'sunsit': 1,
#  'unc': 1,
#  'ms': 7,
#  'goph': 1,
#  'tbk': 1,
#  'macgoph': 1,
#  'cc': 5,
#  'utah': 5,
#  'anoth': 12,
#  'gopherapp': 1,
#  'bio': 4,
#  'indiana': 3,
#  'util': 6,
#  'port': 5,
#  'tcp': 1,
#  'oac': 1,
#  'hsc': 1,
#  'uth': 1,
#  'tmc': 1,
#  'public': 14,
#  'misc': 4,
#  'dosgoph': 1,
#  'exe': 3,
#  'nf': 1,
#  'bcm': 1,
#  'beta': 4,
#  'novel': 1,
#  'lan': 1,
#  'workplac': 2,
#  'lennon': 1,
#  'itn': 1,
#  'med': 2,
#  'umich': 3,
#  'decwindow': 1,
#  'wollongong': 1,
#  'ucx': 1,
#  'job': 2,
#  'ohio': 3,
#  'share': 2,
#  'requir': 9,
#  'mactcp': 1,
#  'fetch': 3,
#  'host': 4,
#  'path': 5,
#  'number': 14,
#  'telnet': 1,
#  'minnesota': 1,
#  'oper': 7,
#  'machin': 5,
#  'consult': 3,
#  'instead': 6,
#  'log': 2,
#  'mous': 2,
#  'scroll': 4,
#  'bar': 4,
#  'etc': 18,
#  'faster': 4,
#  'ie': 3,
#  'tast': 1,
#  'short': 6,
#  'closest': 4,
#  'minim': 1,
#  'lag': 1,
#  'hostnam': 1,
#  'ip': 1,
#  'area': 7,
#  'america': 1,
#  'uiuc': 2,
#  'panda': 1,
#  'uiowa': 1,
#  'sunet': 1,
#  'se': 1,
#  'europ': 1,
#  'info': 9,
#  'anu': 2,
#  'au': 4,
#  'australia': 1,
#  'chalmer': 1,
#  'sweden': 2,
#  'tolten': 1,
#  'puc': 1,
#  'cl': 1,
#  'south': 1,
#  'ecnet': 1,
#  'ec': 1,
#  'ecuador': 1,
#  'gan': 1,
#  'ncc': 1,
#  'jp': 3,
#  'japan': 4,
#  'respons': 6,
#  'furthermor': 3,
#  'basic': 5,
#  'save': 7,
#  'drive': 4,
#  'print': 4,
#  'printer': 4,
#  'retriev': 3,
#  'origin': 13,
#  'april': 3,
#  'microcomput': 1,
#  'help': 24,
#  'sinc': 7,
#  'grown': 1,
#  'fledg': 1,
#  'larg': 5,
#  'contribut': 5,
#  'project': 4,
#  'numer': 3,
#  'count': 3,
#  'behind': 2,
#  'reach': 2,
#  'union': 1,
#  'minneapoli': 1,
#  'mn': 2,
#  'usa': 7,
#  'fax': 8,
#  'intim': 1,
#  'intertwin': 1,
#  'ship': 3,
#  'capabl': 5,
#  'indic': 2,
#  'queri': 2,
#  'remot': 2,
#  'funnel': 1,
#  'result': 4,
#  'web': 1,
#  'either': 9,
#  'built': 3,
#  'nativ': 1,
#  'http': 1,
#  'whole': 4,
#  'chapter': 2,
#  'devot': 1,
#  'ed': 1,
#  'kroll': 1,
#  'oreilli': 1,
#  'editor': 6,
#  'great': 11,
#  'buy': 4,
#  'bunch': 2,
#  'passport': 1,
#  'northwestnet': 1,
#  'guid': 1,
#  'onlin': 3,
#  'jonathan': 1,
#  'kochmer': 1,
#  'publish': 6,
#  'bellevu': 1,
#  'wa': 3,
#  'pp': 3,
#  'isbn': 2,
#  'contact': 10,
#  'nwnet': 1,
#  'student': 4,
#  'harley': 1,
#  'hahn': 1,
#  'mcgraw': 1,
#  'hill': 2,
#  'inc': 4,
#  'connexion': 1,
#  'juli': 3,
#  'interop': 1,
#  'explor': 2,
#  'gopherspac': 1,
#  'v': 9,
#  'n': 11,
#  'subscrib': 2,
#  'isoc': 1,
#  'nri': 1,
#  'reston': 2,
#  'va': 3,
#  'proceed': 1,
#  'twenti': 2,
#  'third': 2,
#  'ietf': 1,
#  'cnri': 1,
#  'section': 5,
#  'canadian': 1,
#  'sri': 1,
#  'discov': 3,
#  'treasur': 1,
#  'computerworld': 1,
#  'administr': 1,
#  'balakrishan': 1,
#  'b': 12,
#  'oct': 1,
#  'spigoph': 1,
#  'spire': 1,
#  'databas': 3,
#  'fall': 4,
#  'workshop': 1,
#  'chapel': 1,
#  'tomer': 1,
#  'technolog': 5,
#  'standard': 15,
#  'librari': 8,
#  'journal': 3,
#  'american': 2,
#  'sept': 1,
#  'rodent': 1,
#  'orient': 5,
#  'index': 4,
#  'computer': 1,
#  'archiv': 5,
#  'offer': 9,
#  'keyword': 1,
#  'menu': 4,
#  'titl': 3,
#  'entir': 3,
#  'archi': 2,
#  'item': 1,
#  'direct': 4,
#  'pointer': 5,
#  'data': 11,
#  'tri': 15,
#  'select': 5,
#  'futiqu': 1,
#  'sc': 1,
#  'unr': 2,
#  'incred': 1,
#  'amount': 7,
#  'availbl': 1,
#  'biologist': 1,
#  'brief': 1,
#  'bdt': 1,
#  'tropic': 1,
#  'base': 9,
#  'biotechnet': 1,
#  'buyer': 1,
#  'catalogu': 1,
#  'tel': 4,
#  'protein': 1,
#  'bank': 2,
#  'header': 4,
#  'chlamydomona': 1,
#  'crystal': 1,
#  'hgmp': 1,
#  'probe': 1,
#  'primer': 1,
#  'museum': 1,
#  'paleontolog': 1,
#  'specimen': 1,
#  'mycdb': 1,
#  'mycobacterium': 1,
#  'drosophila': 1,
#  'flybas': 1,
#  'genbank': 1,
#  'swiss': 1,
#  'prot': 1,
#  'pir': 1,
#  'pdb': 1,
#  'aatdb': 1,
#  'arabidopsi': 1,
#  'thaliana': 1,
#  'acedb': 1,
#  'caenorhabd': 1,
#  'elegan': 1,
#  'compoundkb': 1,
#  'metabol': 1,
#  'compound': 1,
#  'welchlab': 1,
#  'vector': 3,
#  'promot': 1,
#  'nrl': 1,
#  'est': 1,
#  'omi': 1,
#  'embl': 1,
#  'updat': 4,
#  'limb': 1,
#  'keywordspeci': 1,
#  'prosit': 1,
#  'rebas': 1,
#  'restrict': 2,
#  'enzym': 1,
#  'tfd': 1,
#  'strain': 1,
#  'dna': 1,
#  'graingen': 1,
#  'maiz': 1,
#  'clone': 1,
#  'plasmid': 1,
#  'phage': 1,
#  'epd': 1,
#  'eukaryot': 1,
#  'express': 4,
#  'sequenc': 4,
#  'tag': 2,
#  'human': 4,
#  'west': 1,
#  'kabat': 1,
#  'immunolog': 1,
#  'structur': 5,
#  'omim': 1,
#  'mendelian': 1,
#  'inherit': 1,
#  'seqanalref': 1,
#  'analysi': 1,
#  'bibliograph': 1,
#  'ban': 1,
#  'taxonomi': 1,
#  'entri': 6,
#  'fund': 1,
#  'nih': 2,
#  'genom': 1,
#  'doe': 1,
#  'nsf': 2,
#  'usda': 1,
#  'crystallograph': 1,
#  'yeast': 1,
#  'reasearch': 1,
#  'phonebook': 1,
#  'agricultur': 1,
#  'perl': 2,
#  'script': 2,
#  'goe': 4,
#  'begin': 4,
#  'rvpmc': 1,
#  'dd': 2,
#  'nwfocu': 1,
#  'mpdillon': 1,
#  'halcyon': 1,
#  'dillon': 1,
#  'anyon': 27,
#  'code': 15,
#  'concav': 1,
#  'polygon': 6,
#  'break': 2,
#  'set': 9,
#  'convex': 1,
#  'algorithm': 6,
#  'although': 5,
#  'triangul': 1,
#  'satisfi': 3,
#  'task': 3,
#  'partit': 1,
#  'minimum': 6,
#  'piec': 3,
#  'doubt': 1,
#  'known': 6,
#  'download': 7,
#  'beginn': 1,
#  'obvious': 2,
#  'babi': 1,
#  'step': 4,
#  'process': 11,
#  'amongst': 1,
#  'newsgroup': 7,
#  'anyth': 6,
#  'gif': 16,
#  'tif': 3,
#  'compil': 7,
#  'sharewar': 4,
#  'command': 5,
#  'thoma': 3,
#  'helk': 1,
#  'egret': 1,
#  'wet': 1,
#  'uucp': 8,
#  'wq': 1,
#  'currier': 1,
#  'ive': 1,
#  'etch': 1,
#  'digit': 11,
#  'desktop': 3,
#  'particularli': 5,
#  'riverboat': 1,
#  'fee': 6,
#  'river': 1,
#  'boat': 1,
#  'david': 3,
#  'duma': 1,
#  'dmd': 1,
#  'isi': 1,
#  'msstate': 1,
#  'ai': 2,
#  'assum': 3,
#  'angl': 2,
#  'hack': 4,
#  'suppos': 4,
#  'g': 7,
#  'thesi': 1,
#  'supervisor': 1,
#  'pet': 1,
#  'properli': 4,
#  'glori': 1,
#  'money': 4,
#  'enorm': 1,
#  'invest': 1,
#  'resourc': 3,
#  'afford': 2,
#  'recess': 2,
#  'last': 3,
#  'de': 7,
#  'emphasi': 2,
#  'greater': 3,
#  'formal': 1,
#  'approach': 4,
#  'solv': 3,
#  'prove': 3,
#  'theorem': 1,
#  'confer': 3,
#  'ago': 4,
#  'johann': 1,
#  'kleer': 1,
#  'suggest': 8,
#  'everyon': 4,
#  'keyboard': 3,
#  'inclin': 1,
#  'claim': 4,
#  'superhack': 1,
#  'invalid': 1,
#  'remark': 3,
#  'stori': 2,
#  'jackson': 1,
#  'dept': 3,
#  'electr': 4,
#  'eng': 2,
#  'organ': 4,
#  'second': 6,
#  'violin': 1,
#  'fiddl': 1,
#  'firefight': 1,
#  'ensembl': 1,
#  'rome': 1,
#  'branch': 1,
#  'hello': 8,
#  'torso': 1,
#  'scan': 3,
#  'phone': 9,
#  'compani': 5,
#  'midwest': 1,
#  'sanner': 1,
#  'cyberwar': 2,
#  'singl': 6,
#  'cost': 5,
#  'format': 23,
#  'probabl': 6,
#  'softimag': 1,
#  'wavefront': 1,
#  'spline': 1,
#  'forward': 2,
#  'late': 2,
#  'patrick': 2,
#  'maun': 1,
#  'r': 11,
#  'gab': 1,
#  'awiuni': 1,
#  'edvz': 1,
#  'univi': 1,
#  'someon': 15,
#  'model': 6,
#  'sparc': 1,
#  'station': 1,
#  'prefer': 6,
#  'cheap': 3,
#  'richard': 1,
#  'rw': 1,
#  'virginia': 1,
#  'perhap': 4,
#  'becom': 5,
#  'ick': 1,
#  'profession': 4,
#  ...}

# %%
total_vocab = [x for x in DF]
print(total_vocab[:5])
# Out:
# ['articl', 'one', 'nine', 'three', 'may']

# %%
def doc_freq(word):
    c = 0 
    try:
        c=DF[word]
    except:
        pass
    return c


word = "one"
print("Word: ",word," --> frequency: ",doc_freq(word))
# Out:
# Word:  one  --> frequency:  67

# %%
doc = 0
tf_idf = {} 
for i in range(N): 
 
    tokens = processed_text[i] 
 
    counter = Counter(tokens + processed_text[i]) 
    words_count = len(tokens + processed_text[i]) 
 
    for token in np.unique(tokens): 
 
        tf = counter[token]/words_count 
        df = doc_freq(token) 
        idf = np.log((N+1)/(df+1)) 
 
        tf_idf[doc, token] = tf*idf 
    doc += 1

# %%
for i in range(N):
    tokens = processed_text[i]

    counter

# %%
def matching_score(k, query): 
    preprocessed_query = preprocess(query,False) 
    tokens = word_tokenize(str(preprocessed_query)) 
    print("Matching Score") 
    print("\nQuery:", query) 
    print("") 
    print(tokens) 
    query_weights = {}
    for key in tf_idf:
        if key[1] in tokens: 
            try: 
                query_weights[key[0]] += tf_idf[key] 
            except: 
                query_weights[key[0]] = tf_idf[key] 
 
    query_weights = sorted(query_weights.items(), key=lambda x: x[1], reverse=True) 
    print("") 
    l = []
    for i in query_weights[:k]: 
        l.append(i[0]) 
 
    print(l) 

matching_score(2,"I recently got a file describing a library")
# Out:
# No Header
# Matching Score
#
# Query: I recently got a file describing a library
#
# ['recent', 'got', 'file', 'describ', 'librari']
#
# [72, 22]
